# %% [markdown]
# # Please don't edit directly in this document. Create your own copy first.#
#
# # Exercise 1: uOttawa Faculty

# %% [markdown]
# #Extract
# First, let's run the cell below to import neccesary packages. Although most of the commonly used Python libraries are pre-installed, new libraries can be installed as !pip install [package name] or !apt-get install [package name].
#
# ##1. Packages
#
# *   [requests](https://github.com/psf/requests): an elegant and simple HTTP library for Python.
# *   [Beautiful Soup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/): Python library for pulling data out of HTML and XML files

# %%
# import
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Second, set the url of the website from which we'd like to extract data using the requests library that we imported in the first step. If the access was successful, you should see the output as <Response [200]>.
#
# ## 2. Set the URL

# %%
# Set the URL you want to scrape from
url='https://www.uottawa.ca/en/faculties'

# Connect to the URL
response = requests.get(url)
response
# Out:
# <Response [200]>

# %% [markdown]
# Third, parse the html with BeautifulSoup.
#
# ## 3. Parse HTML file

# %%
# Parse HTML and save to BeautifulSoup object
soup = BeautifulSoup(response.text, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if IEMobile 7]><html class="iem7"  lang="en" dir="ltr"><![endif]-->
# <!--[if lt IE 9]><html class="lt-ie9"  lang="en" dir="ltr"><![endif]-->
# <!--[if IE 9]><html class="ie9"  lang="en" dir="ltr"><![endif]-->
# <!--[if (gt IE 9)|(gt IEMobile 7)]><!--><html dir="ltr" lang="en" prefix="fb: http://ogp.me/ns/fb# og: http://ogp.me/ns# article: http://ogp.me/ns/article# book: http://ogp.me/ns/book# profile: http://ogp.me/ns/profile# video: http://ogp.me/ns/video# product: http://ogp.me/ns/product#"><!--<![endif]-->
# <head>
# <title>Faculties | uOttawa | University of Ottawa</title>
# <meta content="width" name="MobileOptimized"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="width=device-width" name="viewport"/>
# <meta charset="utf-8">
# <link href="https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <meta content="The University of Ottawa is the largest bilingual (English-French) university in the world. Located at the heart of Canada’s capital." name="description">
# <meta content="uOttawa, University, visit, Ottawa, Faculty of Arts, Faculty of Law - Civil Law Section, Faculty of Law - Common Law Section, Faculty of Education, Faculty of Engineering, Faculty of Health Sciences, Faculty of Science, Faculty of Social Science, Telfer School of Management" name="keywords">
# <meta content="Drupal 7 (http://drupal.org)" name="generator"/>
# <link href="https://www.uottawa.ca/en/faculties" rel="canonical"/>
# <link href="https://www.uottawa.ca/en/faculties" rel="shortlink"/>
# <meta content="university" property="og:type"/>
# <meta content="https://www.uottawa.ca/en/faculties" property="og:url"/>
# <meta content="Learn more about the University of Ottawa’s nine faculties" property="og:title"/>
# <meta content="Programs and contact information for the faculties of Arts, Education, Engineering, Health Sciences, Law (Civil Law and Common Law sections), Medicine, Science and Social Sciences, and the Telfer School of Management." property="og:description"/>
# <meta content="https://www.uottawa.ca/sites/www.uottawa.ca/files/faculties-1200x628.jpg" property="og:image"/>
# <meta content="https://www.uottawa.ca/sites/www.uottawa.ca/files/faculties-1200x628.jpg" property="og:image:url"/>
# <meta content="https://www.uottawa.ca/sites/www.uottawa.ca/files/faculties-1200x628.jpg" property="og:image:secure_url"/>
# <meta content="image/jpeg" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="628" property="og:image:height"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="Learn more about the University of Ottawa’s nine faculties" name="twitter:title"/>
# <meta content="Programs and contact information for the faculties of Arts, Education, Engineering, Health Sciences, Law (Civil Law and Common Law sections), Medicine, Science and Social Sciences, and the Telfer" name="twitter:description"/>
# <meta content="https://www.uottawa.ca/sites/www.uottawa.ca/files/faculties-1200x628.jpg" name="twitter:image"/>
# <meta content="1200" name="twitter:image:width"/>
# <meta content="628" name="twitter:image:height"/>
# <style>
# @import url("https://www.uottawa.ca/modules/system/system.base.css?pyhydz");
# @import url("https://www.uottawa.ca/modules/system/system.messages.css?pyhydz");
# @import url("https://www.uottawa.ca/modules/system/system.theme.css?pyhydz");
# </style>
# <style>
# @import url("https://www.uottawa.ca/sites/all/modules/contrib/ldap/ldap_user/ldap_user.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/modules/contrib/date/date_api/date.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/modules/contrib/date/date_popup/themes/datepicker.1.7.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/modules/contrib/fences/field.css?pyhydz");
# @import url("https://www.uottawa.ca/modules/node/node.css?pyhydz");
# @import url("https://www.uottawa.ca/modules/search/search.css?pyhydz");
# @import url("https://www.uottawa.ca/modules/user/user.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/modules/contrib/views/css/views.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/modules/contrib/ckeditor/css/ckeditor.css?pyhydz");
# </style>
# <style>
# @import url("https://www.uottawa.ca/sites/all/modules/contrib/ctools/css/ctools.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/modules/contrib/ldap/ldap_servers/ldap_servers.admin.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/modules/contrib/panels/css/panels.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen/custom_panels/rows_1/uottawa_g/uottawa_g.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen/custom_panels/rows_2/uottawa_bc/uottawa_bc.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen/custom_panels/rows_1/uottawa_b/uottawa_b.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/www.uottawa.ca/files/less/ucs_expandable_grid.H-CyLXOLRONKMyN2p0bHRMAgQGx5-rhzPkGkOR4-_1o.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/www.uottawa.ca/files/less/advanced-schemes.MJ2JjdyHLorCA9TIV22WjoP62jUvDyStR1cAnjb0Ofk.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/modules/webcms/widgets/uottawa_core_styles/css/ucs_collapsible.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen/custom_panels/full_width/uottawa_b_full/uottawa_b_full.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/www.uottawa.ca/files/less/view-modes-common.Ev_-CVMfYSbVK4dR0lqhlTP1nGmsvMYmwB_9LYWi9Uo.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/www.uottawa.ca/files/less/corporate.fp1c2h6ZwJivJdOywF09u-4udx5mmkjmQRJVP5duyhs.css?pyhydz");
# </style>
# <style>
# @import url("https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen/css/page_structure.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen/css/layout/uz_dirs.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen/css/layout/uz_paddings.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen/css/layout/uz_widths.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen/css/krumo/uz_krumo.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen/polyfill_details/css/uz_polyfill_details.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/legacy/css/uza_legacy.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/base/css/uza_base.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/icons/css/uza_icons.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/typography/css/uza_typography.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/node/css/uza_node.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/forms/css/uza_forms.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/tables/css/uza_tables.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/events/css/uza_events.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/lists/css/uza_lists.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/common/css/uza_common.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/back_top/css/uza_back_top.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/global_header/css/uza_global_header.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/global_navigation/css/uza_global_navigation.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/site_id/css/uza_site_id.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/local_navigation/css/uza_local_navigation.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/contact_footer/css/uza_contact_footer.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/global_footer/css/uza_global_footer.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/inpage_navigation/css/uza_inpage_navigation.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/corp_home/css/uza_corp_home.css?pyhydz");
# @import url("https://www.uottawa.ca/sites/www.uottawa.ca/files/less/rainbow.KHd6hd1uYPafaLf6bN5ObdT8M0Zwii71S2XwKhV-K28.css?pyhydz");
# </style>
# <style media="print">
# @import url("https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/print/css/print.css?pyhydz");
# </style>
# <style>#header-wrapper{background-image:url('https://www.uottawa.ca/sites/www.uottawa.ca/files/background/20170905-bf-campus-scenic-0021920x420.jpg');background-clip:border-box;background-color:transparent;background-origin:padding-box;background-position:center center;background-repeat:no-repeat;background-size:cover;height:auto !important;margin:0 auto;min-height:100%;width:100%;padding-top:0;position:relative;}
# </style>
# <script src="https://www.uottawa.ca/sites/all/modules/contrib/jquery_update/replace/jquery/1.7/jquery.min.js?v=1.7.2"></script>
# <script src="https://www.uottawa.ca/misc/jquery-extend-3.4.0.js?v=1.7.2"></script>
# <script src="https://www.uottawa.ca/misc/jquery.once.js?v=1.2"></script>
# <script src="https://www.uottawa.ca/misc/drupal.js?pyhydz"></script>
# <script src="https://www.uottawa.ca/sites/all/modules/contrib/jquery_update/replace/ui/external/jquery.cookie.js?v=67fb34f6a866c40d0570"></script>
# <script src="https://www.uottawa.ca/sites/all/modules/contrib/jquery_update/replace/misc/jquery.form.min.js?v=2.69"></script>
# <script src="https://www.uottawa.ca/misc/ajax.js?v=7.67"></script>
# <script src="https://www.uottawa.ca/sites/all/modules/contrib/jquery_update/js/jquery_update.js?v=0.0.1"></script>
# <script src="https://www.uottawa.ca/sites/all/modules/webcms/apps/uottawa_core/uottawa_core.js?pyhydz"></script>
# <script src="https://www.uottawa.ca/sites/all/modules/contrib/custom_search/js/custom_search.js?pyhydz"></script>
# <script src="https://www.uottawa.ca/sites/all/libraries/jquery_nicescroll/jquery.nicescroll.min.js?pyhydz"></script>
# <script src="https://www.uottawa.ca/sites/all/modules/contrib/google_analytics/googleanalytics.js?pyhydz"></script>
# <script src="https://www.uottawa.ca/sites/all/modules/webcms/widgets/uottawa_core_styles/js/ucs_expandable_grid.js?pyhydz"></script>
# <script>(function(i,s,o,g,r,a,m){i["GoogleAnalyticsObject"]=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,"script","https://www.google-analytics.com/analytics.js","ga");ga("create", "UA-6980640-11", {"cookieDomain":"auto"});ga("send", "pageview");</script>
# <script src="https://www.uottawa.ca/sites/all/modules/webcms/config/uottawa_auth/uottawa_auth.js?pyhydz"></script>
# <script src="https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/global_header/js/gnSearchPrimo.js?pyhydz"></script>
# <script src="https://www.uottawa.ca/sites/all/modules/custom/uottawa_ckeditor/plugins/oembed/oembed.js?pyhydz"></script>
# <script src="https://www.uottawa.ca/sites/all/libraries/jquery_mobile/jquery.mobile.custom.min.js?pyhydz"></script>
# <script src="https://www.uottawa.ca/sites/all/libraries/jquery_hoverintent/jquery.hoverIntent.minified.js?pyhydz"></script>
# <script src="https://www.uottawa.ca/misc/progress.js?v=7.67"></script>
# <script src="https://ajax.googleapis.com/ajax/libs/webfont/1.5.18/webfont.js"></script>
# <script src="https://ws.sharethis.com/button/buttons.js?pyhydz"></script>
# <script src="https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen/js/uo_supports_css.js?pyhydz"></script>
# <script src="https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen/polyfill_details/js/uz_polyfill_details.js?pyhydz"></script>
# <script src="https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen/js/uo_details_plus.js?pyhydz"></script>
# <script src="https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/base/js/uza_base.js?pyhydz"></script>
# <script src="https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/global_header/js/uza_global_header.js?pyhydz"></script>
# <script src="https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/site_id/js/uza_site_id.js?pyhydz"></script>
# <script src="https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/local_navigation/js/uza_local_navigation.js?pyhydz"></script>
# <script src="https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/corp_home/js/uza_corp_home.js?pyhydz"></script>
# <script src="https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/back_top/js/uza_back_top.js?pyhydz"></script>
# <script src="https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/global_header/js/banner_gdpr.js?pyhydz"></script>
# <script src="https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/konami/konami.js?pyhydz"></script>
# <script src="https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/konami/rainbow.js?pyhydz"></script>
# <script src="https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/google_fonts/js/uza_google_fonts.js?pyhydz"></script>
# <script>jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"en\/","ajaxPageState":{"theme":"uottawa_zen_assets","theme_token":"CeoCtLOsV6cdEIt1BC8E30oXkq56P-OP8Z5j8I8HNtc","jquery_version":1.7,"js":{"0":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/jquery\/1.7\/jquery.min.js":1,"misc\/jquery-extend-3.4.0.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/ui\/external\/jquery.cookie.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/misc\/jquery.form.min.js":1,"misc\/ajax.js":1,"sites\/all\/modules\/contrib\/jquery_update\/js\/jquery_update.js":1,"sites\/all\/modules\/webcms\/apps\/uottawa_core\/uottawa_core.js":1,"sites\/all\/modules\/contrib\/custom_search\/js\/custom_search.js":1,"sites\/all\/libraries\/jquery_nicescroll\/jquery.nicescroll.min.js":1,"sites\/all\/modules\/contrib\/google_analytics\/googleanalytics.js":1,"sites\/all\/modules\/webcms\/widgets\/uottawa_core_styles\/js\/ucs_expandable_grid.js":1,"1":1,"sites\/all\/modules\/webcms\/config\/uottawa_auth\/uottawa_auth.js":1,"sites\/all\/themes\/custom\/uottawa_zen_assets\/global_header\/js\/gnSearchPrimo.js":1,"sites\/all\/modules\/custom\/uottawa_ckeditor\/plugins\/oembed\/oembed.js":1,"sites\/all\/libraries\/jquery_mobile\/jquery.mobile.custom.min.js":1,"sites\/all\/libraries\/jquery_hoverintent\/jquery.hoverIntent.minified.js":1,"misc\/progress.js":1,"https:\/\/ajax.googleapis.com\/ajax\/libs\/webfont\/1.5.18\/webfont.js":1,"https:\/\/ws.sharethis.com\/button\/buttons.js":1,"sites\/all\/themes\/custom\/uottawa_zen\/js\/uo_supports_css.js":1,"sites\/all\/themes\/custom\/uottawa_zen\/polyfill_details\/js\/uz_polyfill_details.js":1,"sites\/all\/themes\/custom\/uottawa_zen\/js\/uo_details_plus.js":1,"sites\/all\/themes\/custom\/uottawa_zen_assets\/base\/js\/uza_base.js":1,"sites\/all\/themes\/custom\/uottawa_zen_assets\/global_header\/js\/uza_global_header.js":1,"sites\/all\/themes\/custom\/uottawa_zen_assets\/site_id\/js\/uza_site_id.js":1,"sites\/all\/themes\/custom\/uottawa_zen_assets\/local_navigation\/js\/uza_local_navigation.js":1,"sites\/all\/themes\/custom\/uottawa_zen_assets\/corp_home\/js\/uza_corp_home.js":1,"sites\/all\/themes\/custom\/uottawa_zen_assets\/back_top\/js\/uza_back_top.js":1,"sites\/all\/themes\/custom\/uottawa_zen_assets\/global_header\/js\/banner_gdpr.js":1,"sites\/all\/themes\/custom\/uottawa_zen_assets\/konami\/konami.js":1,"sites\/all\/themes\/custom\/uottawa_zen_assets\/konami\/rainbow.js":1,"sites\/all\/themes\/custom\/uottawa_zen_assets\/google_fonts\/js\/uza_google_fonts.js":1},"css":{"modules\/system\/system.base.css":1,"modules\/system\/system.menus.css":1,"modules\/system\/system.messages.css":1,"modules\/system\/system.theme.css":1,"sites\/all\/modules\/contrib\/ldap\/ldap_user\/ldap_user.css":1,"sites\/all\/modules\/contrib\/date\/date_api\/date.css":1,"sites\/all\/modules\/contrib\/date\/date_popup\/themes\/datepicker.1.7.css":1,"modules\/field\/theme\/field.css":1,"modules\/node\/node.css":1,"modules\/search\/search.css":1,"modules\/user\/user.css":1,"sites\/all\/modules\/contrib\/views\/css\/views.css":1,"sites\/all\/modules\/contrib\/ckeditor\/css\/ckeditor.css":1,"sites\/all\/modules\/contrib\/ctools\/css\/ctools.css":1,"sites\/all\/modules\/contrib\/ldap\/ldap_servers\/ldap_servers.admin.css":1,"sites\/all\/modules\/contrib\/panels\/css\/panels.css":1,"sites\/all\/themes\/custom\/uottawa_zen\/custom_panels\/rows_1\/uottawa_g\/uottawa_g.css":1,"sites\/all\/themes\/custom\/uottawa_zen\/custom_panels\/rows_2\/uottawa_bc\/uottawa_bc.css":1,"sites\/all\/themes\/custom\/uottawa_zen\/custom_panels\/rows_1\/uottawa_b\/uottawa_b.css":1,"sites\/all\/modules\/webcms\/widgets\/uottawa_core_styles\/css\/ucs_expandable_grid.css.less":1,"sites\/all\/modules\/webcms\/widgets\/uottawa_advanced_styles\/misc\/advanced-schemes.css.less":1,"sites\/all\/modules\/webcms\/widgets\/uottawa_core_styles\/css\/ucs_collapsible.css":1,"sites\/all\/themes\/custom\/uott ...
# <!--[if lt IE 9]>
#   <script src="/sites/all/themes/custom/uottawa_zen/js/html5.js"></script>
#   <![endif]-->
# <script>
#     var _gaq = _gaq || [];
#     _gaq.push(['_setAccount', 'UA-6980640-11']);
#     _gaq.push(['_trackPageview']);
#
#     (function() {
#       var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#       ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#       var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#     })();
#   </script>
# </meta></meta></meta></head>
# <body class="html not-front not-logged-in no-sidebars page-faculties uos--landing live i18n-en section-faculties page-panels">
# <div class="skip-links">
# <ul>
# <li>
# <a class="element-invisible element-focusable" href="#main-content">Jump to Main Content</a> </li>
# </ul>
# </div>
# <div id="page-wrapper">
# <div class="uol--clearfix" id="global-header-wrapper">
# <div class="uol--page-container" id="global-header">
# <div class="" id="uottawa-global-header">
# <div id="uottawa-logo">
# <a href="https://www.uottawa.ca/en" hreflang="" lang="" rel="home" title="Home"><img alt="University of Ottawa Logo" src="https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/images/uOttawaLogo.svg"/></a> </div>
# <div id="uottawa-mobile-toggles"></div>
# <div id="uoe--global-search-toggle" tabindex="0"></div>
# <div class="uoe--language-switcher"><a class="uoe--switch" href="#"><span class="uoe--globe-icon"></span><span class="uoe--text">Language</span></a><div class="uoe--language-list"><a href="/fr/facultes" hreflang="fr" lang="fr" rel="alternate">Français<span class="uos--invisible"> (passer à la version française de cette page)</span></a><a class="active" href="/en/faculties" hreflang="en" lang="en" rel="alternate">English<span class="uos--invisible"> (switch to the English version of this page)</span></a></div></div><div class="uoe--login-link"><a class="uoe--switch" href="#"><span class="uoe--login-icon"></span><span class="uoe--text">Login</span></a><div class="uoe--login-list"><a href="https://uozone2.uottawa.ca/?language=en">uoZone</a> <a href="https://uottawa.brightspace.com/">Brightspace</a> <a href="https://uozone2.uottawa.ca/?language=en">VirtuO</a> </div></div></div>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet"/>
# <style type="text/css">
# html {
#     background: #fff;
# }
#
# body{
# 	color:#2d2d2c;
# }
#
# h2 {
# 	background: none;
# 	border: none;
# 	color: #2d2d2c;
# }
#
# h3 {
# 	line-height: 1.5;
# }
#
# .cd-gray-boxes h3{
# 	line-height: normal;
# }
#
# h2 a, h3 a, h2 a:visited, h3 a:visited {
# 	color: #2d2d2c;
# 	font-weight:bold;
# }
#
# h4{
# 	font-size: 18px;
# 	font-size: 1.15rem;
# 	color:#80746c;
#         font-weight:bold;
# }
#
# #main-content a:link {
# 	text-decoration-style: solid;
# }
#
# #main-content a:hover{
# 	text-decoration-style: dotted;
# 	color: #54504d;
# }
#
# .uos--header-center h2{
# 	margin: 0;
# 	padding: 45px 0 25px;
# 	text-align:left;
# 	display: block;
# }
#
#
# #main-content p a:link {
# 	color: #8f001a;
# 	text-decoration:none;
# 	font-weight:bold;
# }
#
# #main-content p a:hover {
# 	text-decoration:underline;
# }
#
# /* Dynamic Background */
#
# #header-wrapper{
# 	padding-left:0;
# }
#
# #header-wrapper:before{
# 	content: " ";
# 	width: 100%;
#     height: 100%;
#     position: absolute;
# 	z-index:0;
#     background:linear-gradient(to top right, rgba(0, 0, 0, 0.7), rgba(0, 0, 0, 0) 58%);
# }
#
# #header{
#     position: relative;
#     display: flex;
#     flex-direction: column;
#     padding-top: 230px;
# 	padding-left: 0;
# 	padding-right: 0;
# }
#
# .page-home #header{
# 	padding-top: 150px;
# }
#
#
# .page-home #header > div {
# 	width: 460px;
# 	margin:0;
# }
#
# #site-id .site-id-title {
# 	padding:0;
# 	margin:0;
# 	font-weight: 800;
# 	letter-spacing: 1px;
# 	line-height: 1.05;
# 	font-size:5em;
# 	color: #fff !important;
# 	-webkit-hyphens: none;
# 	-ms-hyphens: none;
# 	hyphens: none;
# }
#
# .page-home #site-id .site-id-title {
# 	font-size:5.5em;
# 	-webkit-user-select: none;  /* Chrome all / Safari all */
# 	-moz-user-select: none;     /* Firefox all */
# 	-ms-user-select: none;      /* IE 10+ */
# 	user-select: none;          /* Likely future */
# }
#
# .page-home.i18n-fr #site-id .site-id-title {
# 	font-size:2.99em;
# }
#
# .home-page-main-link {
# 	margin-top:10px;
# }
#
# .home-page-main-link a{
# 	display:block;
# 	background-color:#8f001a;
# 	padding: 16px 25px;
# 	color:white;
# 	font-size:1.1em;
# 	line-height:1.8;
# 	text-decoration: none;
# 	font-weight:bold;
# 	transition: 300ms ease-in-out;
#     -moz-transition: 300ms ease-in-out;
#     -webkit-transition: 300ms ease-in-out;
# }
#
# .home-page-main-link a:hover {
# 	background-color:#2d2d2c;
# 	transition: .30s ease-in-out;
#     -moz-transition: .30s ease-in-out;
#     -webkit-transition: .30s ease-in-out;
# }
#
# .home-page-main-link .arrow {
#   background-image: url('https://www.uottawa.ca/sites/www.uottawa.ca/files/arrow_white.png');
#   background-repeat: no-repeat;
#   background-position: center;
#   background-size: 70%;
# }
#
# @media only screen and (min-width: 1367px) {
# 	body{
# 		color:#2d2d2c;
# 		font-size: 16px;
# 		font-size: 1rem;
# 	}
#
# 	#header{
# 		max-width: 1185px!important;
# 		padding-top:360px;
# 	}
#
# 	.page-home #header{
# 		padding-top: 280px;
# 	}
#
# 	.uos--standard-width--always, .uos--standard-width {
# 		max-width:1185px!important;
# 	}
# }
#
# @media only screen and (min-width: 996px) and (max-width: 1366px) {
# 	#header{
# 		width: 980px;
# 	}
#
# 	.page-home.i18n-fr #site-id .site-id-title {
# 		font-size: 3.68em;
# 	}
# }
#
# @media only screen and (min-width: 736px) and (max-width: 995px) {
# 	#header{
# 		width: 720px;
# 	}
#
# 	.page-home.i18n-fr #site-id .site-id-title {
# 		font-size: 3.68em;
# 	}
# }
#
# @media (max-width: 735px) and (min-width: 0px){
# 	.cd-nodisplay{
# 		display:none;
# 	}
#
# 	#header{
# 		padding-top: 150px;
# 	}
#
# 	#site-id .site-id-title {
# 		font-size:3em!important;
# 		padding:0 10px;
# 	}
#
# 	.page-home.i18n-fr #site-id .site-id-title {
# 		font-size: 2.5em!important;
# 	}
#
# 	.page-home #header > div {
# 		width: 100%;
# 		margin: auto;
# 		position: relative;
# 		top: 57px;
# 	}
#
# 	.page-home main{
# 		padding-top: 50px;
# 	}
#
# 	.page-home #header .uos--standard-width {
# 		padding: 0;
# 	}
#
# 	#header-wrapper:before{
# 		content: " ";
# 		width: 100%;
# 		height: 100%;
# 		position: absolute;
# 		z-index:0;
# 		background: linear-gradient(to top, rgba(0, 0, 0, 0.6), rgba(0, 0, 0, 0) 40%)
# 	}
#
# 	.uos--header-center h2{
# 		font-size: 2em;
# 	}
# }
#
# /* End Dynamic Background */
#
# /* Home Page - Find your program - Search - Start */
# .cd-search-program{
# 	background-color:#eeeeee;
# 	padding-bottom:20px;
# 	margin-top:60px!important;
# }
#
# .cd-search-program .uos--header-center h2{
# 	text-align:center;
# 	padding: 1em 0 2%;
# }
#
# .homepage-box .content {
#     padding: 15px 8%;
# }
#
# #hp-search form {
#     display:flex;
#     font-size: 1.5em;
# }
#
# #hp-search input[type=text] {
#     padding: 15px;
#     background: #fff;
#     font-size: inherit;
#     font-family: "Roboto", Helvetica, sans-serif;
#     line-height: normal;
# 	border-radius:0;
# 	margin:0;
# 	border-color:black;
# 	box-shadow:none;
# 	flex: 2;
#     width: auto;
# 	color:#2d2d2c;
# }
#
# #hp-search button {
#     background: #8F001A;
#     color: #fff;
#     font-size: inherit;
#     padding: 0 25px;
#     border: none;
#     cursor: pointer;
# 	white-space: nowrap;
# 	margin-left: 15px;
# 	min-width: 30%;
# 	font-weight: bold;
# 	transition: .30s ease-in-out;
#     -moz-transition: .30s ease-in-out;
#     -webkit-transition: .30s ease-in-out;
# }
#
# .fa {
#     display: inline;
# }
#
# @media (max-width: 735px){
# 	#hp-search button {
# 		min-width: 0;
# 	}
# }
#
# #hp-search button:hover{
# 	background: #2d2d2c;
# 	transition: .30s ease-in-out;
#     -moz-transition: .30s ease-in-out;
#     -webkit-transition: .30s ease-in-out;
# }
#
# @media (max-width: 735px) and (min-width: 0px){
# 	#hp-search form {
# 		font-size: 1em;
# 	}
#
# 	.homepage-box .content {
# 		padding: 0;
# 	}
#
# 	.cd-search-button-text {
# 		position: absolute;
# 		width: 1px;
# 		height: 1px;
# 		padding: 0;
# 		margin: -1px;
# 		overflow: hidden;
# 		clip: rect(0, 0, 0, 0);
# 		border: 0;
# 	}
# }
#
# /* Home Page - Find your program - Search - End */
#
# /* Stories - Start */
#
# .cd-stories .uos--list--links{
# 	display:flex;
# 	margin:0 -1.6%!important;
# }
#
# .cd-stories .uos--list--links > li{
# 	float:none!important;
# 	padding:0 1.6%!important;
# }
#
# .cd-stories .uos--list--links > li img{
# 	padding-bottom:30px;
# 	border-bottom: 2px solid #8f001a;
# }
#
# .cd-stories .cmb-title{
# 	margin:20px 0;
# }
#
# @media (max-width: 735px) and (min-width: 0px){
# 	.cd-stories .uos--list--links {
# 		flex-direction: column;
# 		margin:0!important;
# 	}
#
# 	.cd-stories .uos--list--links > li{
# 		display:grid;
# 		grid-template-columns: 33.33% auto;
# 		grid-template-rows: max-content;
# 		grid-auto-flow: column;
# 		grid-gap: 0 15px;
# 		padding:0 0 30px!important;
# 		border-bottom: 2px solid #8f001a;
# 	}
#
# 	.cd-stories .uos--list--links > li:last-child{
# 		padding:0!important;
# 		border-bottom: none;
# 	}
#
# 	.cd-stories .uos--list--links > li > img{
# 		grid-row: 1 / 3;
# 		padding-bottom:0;
# 		border-bottom: none;
# 	}
#
# 	.cd-stories .cmb-title{
# 		line-height:1.3;
# 		margin:0;
# 		/*font-size: 16px;
# 		font-size: 1rem;*/
# 	}
#
# 	.cd-stories p{
# 		margin-bottom:0;
# 		font-size: 13px;
# 		font-size: 0.8125rem;
# 	}
# }
#
#
# /* Stories - End */
#
# /* Categories - Start */
#
# .cd-categories .uos--list--links{
# 	display:flex;
# 	margin:0 -1.6%!important;
# }
#
# .cd-categories .uos--list--links a {
# 	color:black;
# }
#
# .cd-categories .uos--list--links > li{
# 	float:none!important;
# 	padding:0 1.6%!important;
# }
#
# .cd-categories .uos--list--links > li img{
# 	padding-bottom:30px;
# 	border-bottom: 2px solid #8f001a;
# 	margin-bottom: 30px;
# }
#
# .cd-categories .cd-title{
# 	margin:0 0 20px;
# }
#
# .cd-categories p{
# 	line-height: 1.5;
# }
#
# @media (max-width: 735px) and (min-width: 0px){
# 	.cd-categories .uos--list--links {
# 		flex-direction: column;
# 		margin:0 0 30px!important;
# 	}
#
# 	.cd-categories .uos--list--links > li{
# 		display:grid;
# 		grid-template-columns: 33.33% auto;
# 		grid-gap: 0 15px;
# 		padding:0 0 30px!important;
# 		border-bottom: 2px solid #8f001a;
# 	}
#
# 	.cd-categories .uos--list--links > li:last-child{
# 		padding:0!important;
# 		border-bottom: none;
# 	}
#
# 	.cd-categories .uos--list--links > li > img{
# 		padding-bottom:0;
# 		border-bottom: none;
# 		margin-bottom: 0;
# 	}
#
# 	.cd-categories .uos--list--links > li > ul, .cd-categories .uos--list--links > li > ul > li:first-child, .cd-categories .uos--list--links > li > ul > li:last-child{
# 		margin:0;
# 	}
#
# 	.cd-categories .cd-title{
# 		grid-column: 1 / 3;
# 		line-height:1.3;
# 	}
#
# 	.cd-categories p{
# 		margin-bottom:0;
# 		font-size: 13px;
# 		font-size: 0.8125rem;
# 	}
# }
#
#
# /* Categories - End */
#
#
# /* Home page - Contact us - Start */
#
# .cd-contact-us{
# 	padding:45px 0;
# }
#
# .cd-contact-us .cd-contact-us-text{
# 	padding-right:10px;
# }
#
# .cd-contact-us .cd-contact-us-text p{
# 	font-size: 24px;
#     font-size: 1.5rem;
# 	margin:0;
# }
#
# #main-content .cd-contact-us .cd-contact-us-button a.uos--button{
# 	background: #8f001a;
# 	float:right;
# 	font-size: 16px;
#     font-size: 1rem;
# 	min-width: 100%;
# 	text-align:center;
# 	padding:25px 0;
# 	margin:0;
# 	text-decoration:none;
# 	font-weight:bold;
# 	transition: 300ms ease-in-out;
#     -moz-transition: 300ms ease-in-out;
#     -webkit-transition: 300ms ease-in-out;
# }
#
# #main-content .cd-contact-us .cd-contact-us-button a.uos--button:hover, #main-content .cd-contact-us .cd-contact-us-button a.uos--button:active{
# 	background: #2d2d2c;
# 	color:#FFF;
# 	transition: .30s ease-in-out;
#     -moz-transition: .30s ease-in-out;
#     -webkit-transition: .30s ease-in-out;
# }
#
# .cd-contact-us .uottawa-F-1{
#     display: flex;
#     align-items: center;
# }
#
# @media (max-width: 735px) and (min-width: 0px){
# 	.cd-contact-us{
# 		padding:30px 0;
# 	}
#
# 	.cd-contact-us .uottawa-F-1{
# 		display:block;
# 	}
#
# 	.cd-contact-us .cd-contact-us-button{
# 		margin:0 10px;
# 		width:auto;
# 	}
# }
#
# /* Home page - Contact us - End */
#
# /* Students page - Key Blocks - Start */
#
# .cd-key-blocks{  }
#
# .cd-key-blocks .uos--list--links{
# 	display:flex;
# 	margin:0 -1.6% 35px!important;
# }
#
# .cd-key-blocks .uos--list--links > li{
# 	float:none!important;
# 	padding:0 1.6%!important;
# 	display: flex;
#     flex-direction: column;
#     justify-content: space-between;
# 	margin-top:0;
# 	margin-bottom:1em!important;
# }
#
# @media (max-width: 735px) and (min-width: 0px){
# 	.cd-key-blocks .uos--list--links {
# 		flex-direction: column;
# 		margin:0 auto 45px!important;
# 	}
#
# 	.cd-key-blocks .uos--list--links > li{
# 		padding:0!important;
# 	}
#
# 	.cd-key-blocks p{
# 		display:none;
# 	}
# }
#
# .cd-key-blocks p{
# 	font-size: 16px;
#     font-size: 1rem;
# 	margin-top:0;
# }
#
# #main-content .cd-key-blocks a.uos--button{
# 	background: #8f001a;
# 	float:right;
# 	font-size: 16px;
#     font-size: 1rem;
# 	font-weight: bold;
# 	min-width: 100%;
# 	text-align:center;
# 	padding:25px 0;
# 	margin:0;
# 	text-decoration:none;
# 	font-weight:bold;
# 	transition: 300ms ease-in-out;
#     -moz-transition: 300ms ease-in-out;
#     -webkit-transition: 300ms ease-in-out;
# }
#
# #main-content .cd-key-blocks a.uos--button:hover, #main-content .cd-key-blocks a.uos--button:active{
# 	background: #2d2d2c;
# 	color:#FFFFFF;
# 	transition: .30s ease-in-out;
#     -moz-transition: .30s ease-in-out;
#     -webkit-transition: .30s ease-in-out;
# }
#
# /* Students page - Key Blocks - End */
#
# /* A few quick fixes */
#
# .cd-readmore p{
# 	margin: 10px 0 60px;
# }
#
# @media (max-width: 735px) and (min-width: 0px){
# 	.cd-readmore p{
# 		margin: 10px 0 45px;
# 	}
# }
#
# #main-content .cd-readmore a, #main-content .cd-readmore a:link{
# 	color:#2d2d2c;
# 	font-weight:bold;
# }
#
# .cd-faculty-content h2{
# 	padding: 0;
#     margin: 0 0 1em;
# 	font-size: 2em;
# }
#
# .cd-search-program .cd-readmore p{
# 	margin-top: 2%;
# }
#
# .cd-extra-margin-top{
# 	margin-top: 60px!important;
# }
#
# .cd-extra-margin-bottom{
# 	margin-bottom: 45px!important;
# }
#
# .cd-small-extra-margin-top{
# 	margin-top: 45px!important;
# }
#
# .cd-small-extra-margin-bottom{
# 	margin-bottom: 30px!important;
# }
#
# @media (max-width: 735px) and (min-width: 0px){
# 	.cd-faculty-content h2 {
# 		font-size: 1.4em;
# 	}
#
# 	.cd-faculty-content .uol--width--750{
# 		width: 75%;
# 	}
#
# 	.cd-faculty-content .uol--width--250{
# 		width: 25%;
# 	}
#
# 	.cd-search-program{
# 		margin: 18px 10px 0!important;
# 		width: auto!important;
# 	}
#
# 	.cd-search-program .cd-readmore p{
# 		margin-top: 6%;
# 	}
#
# 	.cd-extra-margin-top{
# 		margin-top: 45px!important;
# 	}
#
# 	.cd-small-extra-margin-top{
# 		margin-top: 30px!important;
# 	}
#
# 	.cd-small-extra-margin-bottom{
# 		margin-bottom: 35px!important;
# 	}
# }
#
# hr {
#     background-color: #aca39a;
# 	margin-top:0;
# 	margin-bottom:0;
# }
# .uos--header-center h2{
# 	font-size: 2.375rem;
# }
# #contact-footer-wrapper{
# 	padding-bottom:0;
# }
#
# .cd-black-links a{
# 	color:black;
# }
#
# .cd-campus-tours{
# 	padding-top:30px;
# }
#
# .cd-SL{
# 	padding-top:3.5%;
# }
#
# .pane-students-our-services .cd-readmore{
# 	margin-top: 1%;
# }
#
# @media only screen and (min-width: 1367px){
# 	.cd-local-footer-container .cd-local-footer-right{
# 		margin-top:15px!important;
# 	}
# }
#
# .uoe--back-top:hover{
# 	background-color:#2d2d2c!important;
# 	opacity:1;
# 	transition: .30s ease-in-out;
#     -moz-transition: .30s ease-in-out;
#     -webkit-transition: .30s ease-in-out;
# }
#
#
# </style>
# <script>
#  jQuery(window).on('load', function() {
#   //console.log(checkCookie('not_now'));
#   //adminPanel();
#  });
#
# function setCookie(name, value, days) {
#   var d = new Date();
#   d.setTime(d.getTime() + (days * 24 * 60 * 60 * 1000));
#   var expires = "expires=" + d.toUTCString();
#   document.cookie = name + "=" + value + ";" + expires + ";path=/";
# }
#
# function getCookie(name) {
#   var cookie_name = name + "=";
#   var ca = document.cookie.split(';');
#   for(var i = 0; i < ca.length; i++) {
#     var c = ca[i];
#     while (c.charAt(0) == ' ') {
#       c = c.substring(1);
#     }
#     if (c.indexOf(cookie_name) == 0) {
#       return c.substring(cookie_name.length, c.length);
#     }
#   }
#   return "";
# }
#
# function checkCookie(name) {
#   var not_now = getCookie('not_now');
#   switch (not_now) {
#     case 'no' :
#       console.log('cookie set to "no" ');
#       return 'no';
#       break;
#
#     case 'yes' :
#       console.log('cookie set to "yes" ');
#       return 'yes';
#       break;
#
#     default:
#       console.log('cookie not set');
#       setCookie('not_now', 'no', 0); //session cookie
#       return 'no';
#   }
# }
#
# function deleteCookie(name) {
#   setCookie(name,"",-1);
# }
#
# function adminPanel() {
#   var button_set = document.createElement("button");
#   button_set.innerHTML = "SetCookie";
#   var body = document.getElementById("--2");
#   body.appendChild(button_set);
#   button_set.addEventListener ("click", function() {
#     setCookie('not_now', 'yes', 1);
#   });
#
#   var button_clear = document.createElement("button");
#   button_clear.innerHTML = "ClearCookie";
#   var body = document.getElementById("--2");
#   body.appendChild(button_clear);
#   button_clear.addEventListener ("click", function() {
#     setCookie('not_now', 'no', 0);
#   });
#
#   var button_check = document.createElement("button");
#   button_check.innerHTML = "CheckCookie";
#   var body = document.getElementById("--2");
#   body.appendChild(button_check);
#   button_check.addEventListener ("click", function() {
#     checkCookie('not_now');
#   });
# }
# </script>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js"></script>
# <script src="https://uottawa.ca/json/uoweb/jquery.ellipsis.js"></script>
# <script>
#   jQuery(window).on('load', function() {
#     jQuery('.ellipsis_container').ellipsis({
#       lines: 2,             // force ellipsis after a certain number of lines. Default is 'auto'
#       ellipClass: 'ellip',  // class used for ellipsis wrapper and to namespace ellip line
#       responsive: true      // set to true if you want ellipsis to update on window resize. Default is false
#     });
#   });
# </script>
# <style type="text/css">
#
# /* Communication Marketing and Brand specific CSS */
# /* @import "cmb-three-columns"; */
# .ellip {
#   display: block;
#   height: auto;
# }
#
# .ellip-line {
#   display: inline-block;
#   text-overflow: ellipsis;
#   white-space: nowrap;
#   word-wrap: normal;
#   max-width: 100%;
# }
#
# .ellip,
# .ellip-line {
#   position: relative;
#   overflow: hidden;
# }
#
# .cd-container .cd-1col .uoe--list {
#   display: -ms-grid;
#   display: grid;
#   grid-auto-rows: 1fr;
#   -ms-grid-columns: 1fr;
#   grid-template-columns: 1fr;
# }
# .cd-container .cd-1col .uoe--list li:nth-child(1) {
#   -ms-grid-row: 1;
#   -ms-grid-column: 1;
#   margin-right: 20px !important;
#   margin-bottom: 20px !important;
# }
# .cd-container .cd-1col .uoe--list li:nth-child(2) {
#   -ms-grid-row: 2;
#   -ms-grid-column: 1;
#   margin-right: 20px !important;
#   margin-bottom: 20px !important;
# }
# .cd-container .cd-1col .uoe--list li:nth-child(3) {
#   -ms-grid-row: 3;
#   -ms-grid-column: 1;
#   margin-right: 20px !important;
#   margin-bottom: 20px !important;
# }
# .cd-container .cd-1col-red-sided .uoe--list {
#   display: -ms-grid;
#   display: grid;
#   grid-auto-rows: 1fr;
#   -ms-grid-columns: 1fr;
#   grid-template-columns: 1fr;
# }
# .cd-container .cd-1col-red-sided .uoe--list li:nth-child(1) {
#   -ms-grid-row: 1;
#   -ms-grid-column: 1;
#   margin-bottom: 30px !important;
# }
# .cd-container .cd-1col-red-sided .uoe--list li:nth-child(2) {
#   -ms-grid-row: 2;
#   -ms-grid-column: 1;
#   margin-bottom: 30px !important;
# }
# .cd-container .cd-1col-red-sided .uoe--list li:nth-child(3) {
#   -ms-grid-row: 3;
#   -ms-grid-column: 1;
#   margin-bottom: 30px !important;
# }
# .cd-container .cd-2cols .uoe--list {
#   display: -ms-grid;
#   display: grid;
#   grid-auto-rows: 1fr;
#   -ms-grid-columns: 1fr 20px 1fr;
#   grid-template-columns: 1fr 1fr;
#   grid-gap: 0 20px;
# }
# .cd-container .cd-2cols .uoe--list li:nth-child(1) {
#   -ms-grid-row: 1;
#   -ms-grid-column: 1;
#   margin-right: 20px !important;
#   margin-bottom: 20px !important;
# }
# .cd-container .cd-2cols .uoe--list li:nth-child(2) {
#   -ms-grid-row: 1;
#   -ms-grid-column: 3;
#   margin-bottom: 20px !important;
# }
# .cd-container .cd-2cols .uoe--list li:nth-child(3) {
#   -ms-grid-row: 2;
#   -ms-grid-column: 1;
#   margin-right: 20px !important;
#   margin-bottom: 20px !important;
# }
# .cd-container .cd-2cols .uoe--list li:nth-child(4) {
#   -ms-grid-row: 2;
#   -ms-grid-column: 3;
#   margin-bottom: 20px !important;
# }
# .cd-container .cd-2cols .uoe--list li:nth-child(5) {
#   -ms-grid-row: 3;
#   -ms-grid-column: 1;
#   margin-right: 20px !important;
#   margin-bottom: 20px !important;
# }
# .cd-container .cd-2cols .uoe--list li:nth-child(6) {
#   -ms-grid-row: 3;
#   -ms-grid-column: 3;
#   margin-bottom: 20px !important;
# }
# .cd-container .cd-2cols .uoe--list li:nth-child(7) {
#   -ms-grid-row: 4;
#   -ms-grid-column: 1;
#   margin-right: 20px !important;
#   margin-bottom: 20px !important;
# }
# .cd-container .cd-2cols .uoe--list li:nth-child(8) {
#   -ms-grid-row: 4;
#   -ms-grid-column: 3;
#   margin-bottom: 20px !important;
# }
# .cd-container .cd-2cols .uoe--list li:nth-child(9) {
#   -ms-grid-row: 5;
#   -ms-grid-column: 1;
#   margin-right: 20px !important;
#   margin-bottom: 20px !important;
# }
# .cd-container .cd-2cols .uoe--list li:nth-child(10) {
#   -ms-grid-row: 5;
#   -ms-grid-column: 3;
#   margin-bottom: 20px !important;
# }
# .cd-container .cd-2cols-red-sided .uoe--list {
#   display: -ms-grid;
#   display: grid;
#   grid-auto-rows: 1fr;
#   -ms-grid-columns: 1fr 0 1fr;
#   grid-template-columns: 1fr 1fr;
#   grid-gap: 0 0;
# }
# .cd-container .cd-2cols-red-sided .uoe--list li:nth-child(1) {
#   -ms-grid-row: 1;
#   -ms-grid-column: 1;
#   margin-right: 10px !important;
#   margin-bottom: 30px !important;
# }
# .cd-container .cd-2cols-red-sided .uoe--list li:nth-child(2) {
#   -ms-grid-row: 1;
#   -ms-grid-column: 3;
#   margin-bottom: 30px !important;
# }
# .cd-container .cd-2cols-red-sided .uoe--list li:nth-child(3) {
#   -ms-grid-row: 2;
#   -ms-grid-column: 1;
#   margin-right: 10px !important;
#   margin-bottom: 30px !important;
# }
# .cd-container .cd-2cols-red-sided .uoe--list li:nth-child(4) {
#   -ms-grid-row: 2;
#   -ms-grid-column: 3;
#   margin-bottom: 30px !important;
# }
# .cd-container .cd-3cols .uoe--list {
#   display: -ms-grid;
#   display: grid;
#   grid-auto-rows: 1fr;
#   -ms-grid-columns: 1fr 20px 1fr 20px 1fr;
#   grid-template-columns: 1fr 1fr 1fr;
#   grid-gap: 0 20px;
# }
# .cd-container .cd-3cols .uoe--list li:nth-child(1) {
#   -ms-grid-row: 1;
#   -ms-grid-column: 1;
#   margin-right: 20px !important;
#   margin-bottom: 20px !important;
# }
# .cd-container .cd-3cols .uoe--list li:nth-child(2) {
#   -ms-grid-row: 1;
#   -ms-grid-column: 3;
#   margin-right: 20px !important;
#   margin-bottom: 20px !important;
# }
# .cd-container .cd-3cols .uoe--list li:nth-child(3) {
#   -ms-grid-row: 1;
#   -ms-grid-column: 5;
#   margin-bottom: 20px !important;
# }
# .cd-container .cd-gray-boxes .uoe--list-item {
#   background-color: #eee;
#   padding: 1.875em !important;
#   margin: 0 !important;
# }
# .cd-container .cd-gray-box {
#   display: -webkit-box;
#   display: -ms-flexbox;
#   display: flex;
#   -webkit-box-orient: vertical;
#   -webkit-box-direction: normal;
#   -ms-flex-direction: column;
#   flex-direction: column;
#   background-color: #eee;
#   padding: 1.875em;
# }
# .cd-container .cd-gray-box .cd-red-button {
#   width: 50%;
#   -ms-flex-item-align: end;
#   align-self: flex-end;
# }
# .cd-container .cd-red-sided-boxes .uoe--list-item {
#   border-left: 2px solid #8f001a;
#   padding: 0 1.25em !important;
#   margin: 0 !important;
# }
# .cd-container .cd-red-sided-boxes h3 {
#   margin: 0;
#   font-weight: bold;
# }
# .cd-container .cd-red-sided-boxes p {
#   margin: 1em 0 0.2em;
# }
# .cd-container .cd-image-padding-right-small {
#   padding-right: 10px;
# }
# .cd-container .cd-image-padding-right-medium {
#   padding-right: 20px;
# }
# .cd-container .cd-image-padding-right-large {
#   padding-right: 30px;
# }
# .cd-container .cd-image-padding-bottom-small {
#   padding-bottom: 10px;
# }
# .cd-container .cd-image-padding-bottom-medium {
#   padding-bottom: 20px;
# }
# .cd-container .cd-image-padding-bottom-large {
#   padding-bottom: 30px;
# }
# .cd-container .cd-image-padding-left-small {
#   padding-left: 10px;
# }
# .cd-container .cd-image-padding-left-medium {
#   padding-left: 20px;
# }
# .cd-container .cd-image-padding-left-large {
#   padding-left: 30px;
# }
# .cd-container .cs-content-wrapper {
#   height: 100%;
# }
# .cd-container .cs-content-wrapper .pane-snippet {
#   height: 100%;
# }
# .cd-container .cs-content-wrapper .pane-snippet .uos--standard-width {
#   height: 100%;
# }
# .cd-container .cs-content-wrapper .pane-snippet .uos--standard-width .uoe--content {
#   height: 100%;
# }
# .cd-container .cd-support-img {
#   height: 100%;
#   background-size: cover;
#   background-position: center;
# }
# .cd-container .cd-mobile-only {
#   display: none;
# }
#
# .cd-list-3cols {
#   -webkit-column-count: 3;
#   column-count: 3;
# }
# .cd-list-3cols li {
#   margin: 0.5em 0;
#   display: inline-block;
# }
#
# .cd-gray-links a {
#   color: #2d2d2c;
# }
#
# .cd-border {
#   border-top: 3px solid #8f001a;
# }
#
# .cd-faculty-box {
#   border: 1px solid #000000;
#   padding: 20px;
#   margin-bottom: 40px;
# }
# .cd-faculty-box .collapsible-content {
#   margin-top: 20px;
#   border-top: 1px solid #aca39a;
# }
# .cd-faculty-box .cd-faculty-image {
#   padding-right: 40px;
# }
# .cd-faculty-box .cd-faculty-container {
#   display: -webkit-box;
#   display: -ms-flexbox;
#   display: flex;
# }
# .cd-faculty-box .cd-map-container {
#   width: auto;
#   margin-left: 10px;
# }
# .cd-faculty-box .cd-map-container span {
#   margin: 0;
#   font-color: #8f001a;
# }
# .cd-faculty-box .cd-map-container a {
#   height: 100%;
#   padding-bottom: 2.2em;
#   display: -webkit-box;
#   display: -ms-flexbox;
#   display: flex;
#   -webkit-box-align: end;
#   -ms-flex-align: end;
#   align-items: flex-end;
# }
# .cd-faculty-box .cd-map-container a:hover .cd-map-pointer {
#   opacity: 0.5;
# }
# .cd-faculty-box .cd-map-container .cd-map-pointer {
#   background-image: url("https://www.uottawa.ca/sites/www.uottawa.ca/files/map_pointer.png");
#   background-repeat: no-repeat;
#   background-position: left bottom 4px;
#   height: 25px;
#   width: 20px;
#   opacity: 1;
# }
# .cd-faculty-box .cd-faculties-img-text {
#   padding-bottom: 20px;
#   margin-bottom: 20px;
#   border-bottom: 1px solid #aca39a;
# }
# .cd-faculty-box .cd-link-container {
#   font-size: 1.07rem;
#   font-weight: 700;
#   padding-left: 15px;
# }
# .cd-faculty-box .cd-link-container p {
#   margin: 0;
#   font-color: #8f001a;
# }
# .cd-faculty-box .cd-link-container a.cd-arrow {
#   text-decoration: none !important;
# }
# .cd-faculty-box details {
#   margin-bottom: 0;
#   border: 0;
# }
# .cd-faculty-box details.collapsible > summary {
#   color: #8f001a !important;
#   background-color: #ffffff !important;
#   background: none !important;
#   border: 0 !important;
#   padding-top: 0 !important;
#   padding-bottom: 0 !important;
# }
# .cd-faculty-box details.collapsible > summary:before {
#   content: "+" !important;
#   background: none !important;
#   opacity: 1 !important;
#   top: 0 !important;
#   font-size: 1.07rem;
# }
# .cd-faculty-box details.collapsible[open] > summary {
#   background: none !important;
# }
# .cd-faculty-box details.collapsible[open] > summary:before {
#   content: "x" !important;
# }
# .cd-faculty-box summary {
#   margin-bottom: 0;
#   padding-left: 12px;
# }
# .cd-faculty-box .uos--endline:after {
#   height: 0 !important;
# }
# .cd-faculty-box .uos--endline--gradient {
#   padding-bottom: 0 !important;
# }
# .cd-faculty-box .uos--endline--gradient:before {
#   height: 0 !important;
# }
# .cd-faculty-box .uos--colour-profile--background--after:after {
#   background-color: #ffffff !important;
# }
# .cd-faculty-box .uol--dir--rtl {
#   text-decoration: underline solid;
# }
#
# .uoe--back-top {
#   display: none;
# }
#
# .cd-local-footer-container {
#   display: -webkit-box;
#   display: -ms-flexbox;
#   display: flex;
# }
# .cd-local-footer-container .cd-local-footer-left {
#   float: left;
#   width: 100%;
# }
# .cd-local-footer-container .cd-local-footer-right {
#   float: right;
#   width: auto;
#   -ms-flex-item-align: end;
#   align-self: flex-end;
#   margin-left: 10px;
# }
# .cd-local-footer-container .uoe--back-top {
#   background-image: url("https://www.uottawa.ca/sites/www.uottawa.ca/files/back-to-top.png");
#   background-repeat: no-repeat;
#   background-position: center center;
#   background-size: 60%;
#   background-color: #8f001a;
#   display: inline-block;
#   margin-right: 0;
#   margin-bottom: 0;
#   min-width: 50px;
#   min-height: 36px;
#   transition: 0.3s ease-in-out;
#   -moz-transition: 0.3s ease-in-out;
#   -webkit-transition: 0.3s ease-in-out;
# }
#
# details > summary::-webkit-details-marker {
#   display: none;
# }
#
# @media (min-width: 736px) and (max-width: 995px) {
#   .cd-container .cd-gray-box .cd-red-button {
#     width: 100%;
#   }
# }
# @media (min-width: 0px) and (max-width: 735px) {
#   .cd-container .cd-1col .uoe--list {
#     -ms-grid-columns: 1fr 20px 1fr;
#     grid-template-columns: 1fr 1fr;
#     -ms-grid-rows: auto;
#     grid-template-rows: auto;
#     grid-gap: 20px 20px;
#   }
#   .cd-container .cd-1col .uoe--list li:nth-child(1) {
#     -ms-grid-row: 1;
#     -ms-grid-column: 1;
#     margin-right: 20px !important;
#     margin-bottom: 20px !important;
#   }
#   .cd-container .cd-1col .uoe--list li:nth-child(2) {
#     -ms-grid-row: 2;
#     -ms-grid-column: 1;
#     margin-right: 20px !important;
#     margin-bottom: 20px !important;
#   }
#   .cd-container .cd-1col .uoe--list li:nth-child(3) {
#     -ms-grid-row: 3;
#     -ms-grid-column: 1;
#     margin-right: 20px !important;
#     margin-bottom: 20px !important;
#   }
#   .cd-container .cd-1col .uoe--list h3 {
#     font-size: 14px;
#     text-align: center;
#   }
#   .cd-container .cd-1col-red-sided .uoe--list {
#     display: block;
#   }
#   .cd-container .cd-1col-red-sided .uoe--list li:nth-child(1) {
#     margin-bottom: 20px !important;
#   }
#   .cd-container .cd-1col-red-sided .uoe--list li:nth-child(2) {
#     margin-bottom: 20px !important;
#   }
#   .cd-container .cd-1col-red-sided .uoe--list li:nth-child(3) {
#     margin-bottom: 20px !important;
#   }
#   .cd-container .cd-2cols-red-sided .uoe--list {
#     display: block;
#   }
#   .cd-container .cd-2cols-red-sided .uoe--list li:nth-child(1) {
#     margin-right: 0;
#     margin-bottom: 20px !important;
#   }
#   .cd-container .cd-2cols-red-sided .uoe--list li:nth-child(2) {
#     margin-right: 0;
#     margin-bottom: 20px !important;
#   }
#   .cd-container .cd-2cols-red-sided .uoe--list li:nth-child(3) {
#     margin-right: 0;
#     margin-bottom: 20px !important;
#   }
#   .cd-container .cd-2cols-red-sided .uoe--list li:nth-child(4) {
#     margin-right: 0;
#     margin-bottom: 20px !important;
#   }
#   .cd-container .cd-2cols h3 {
#     font-size: 14px;
#     text-align: center;
#   }
#   .cd-container .cd-3col .uoe--list {
#     -ms-grid-columns: 1fr 20px 1fr;
#     grid-template-columns: 1fr 1fr;
#     -ms-grid-rows: auto;
#     grid-template-rows: auto;
#     grid-gap: 20px 20px;
#   }
#   .cd-container .cd-3col .uoe--list li:nth-child(1) {
#     -ms-grid-row: 1;
#     -ms-grid-column: 1;
#     margin-right: 20px !important;
#     margin-bottom: 20px !important;
#   }
#   .cd-container .cd-3col .uoe--list li:nth-child(2) {
#     -ms-grid-row: 1;
#     -ms-grid-column: 3;
# ...
# </div> </div>
# </div>
# </div>
# </div>
# </div>
# <div class="uottawa-BC-2 uol--clearfix">
# <div class="uottawa-BC-2-1o2 uol--region uol--width--500 uol--dir--ltr">
# <div class="panel-pane pane-snippet">
# <div class="uos--standard-width">
# <div class="uoe--view-mode uoe--view-mode--content-body content-snippet uoe--content">
# <h4>Undergraduate studies</h4>
# <p>55 Laurier Avenue East (DMS), room 1100</p>
# <p>Tel.: 613-562-5731<br/>
# Fax: 613-562-5164<br/>
# <a href="mailto:info@telfer.uOttawa.ca">info@telfer.uOttawa.ca</a></p> </div>
# </div>
# </div>
# </div>
# <div class="uottawa-BC-2-2o2 uol--region uol--width--500 uol--dir--ltr">
# <div class="panel-pane pane-snippet">
# <div class="uos--standard-width">
# <div class="uoe--view-mode uoe--view-mode--content-body content-snippet uoe--content">
# <h4>Graduate studies</h4>
# <p>55 Laurier Avenue East (DMS), room 4160</p>
# <p>Tel.: 613-562-5884<br/>
# Fax: 613-562-5912<br/>
# <a href="mailto:graduate@telfer.uOttawa.ca">graduate@telfer.uOttawa.ca</a></p> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="panel-pane pane-panels-mini pane-telfer-school-of-management-depa">
# <div class="uos--standard-width">
# <div class="uottawa-B">
# <div class="uottawa-B-1">
# <div class="uottawa-B-1-1o1 uol--region">
# <div class="uos--color-scheme--arts--overlay uos--color-scheme--arts--background uos--color-scheme--arts--header uol--gutter-top--500 cs-parent-wrapper"><details class="collapsible uos--container uol--width--1000 cs-widget" id=""><summary class="uoe--color-scheme--header">View departments, schools and institutes</summary>
# <div class="ucs--expandable-grid collapsible-content uos--endline uos--colour-profile--background--after uos--endline--gradient uol--padding--large uos--view-mode-block--clearfix cs-content-wrapper"><div class="panel-pane pane-snippet">
# <div class="uos--standard-width">
# <div class="uoe--view-mode uoe--view-mode--content-body content-snippet uoe--content">
# <ul class="uos-list-links cd-list-3cols cd-gray-links">
# <li><a href="https://telfer.uottawa.ca/en/bcom/your-program-of-study/program-options/accounting">Accounting</a></li>
# <li><a href="https://telfer.uottawa.ca/en/bcom/your-program-of-study/program-options/entrepreneurship">Entrepreneurship</a></li>
# <li><a href="https://telfer.uottawa.ca/en/emba">Executive MBA</a></li>
# <li><a href="https://telfer.uottawa.ca/en/bcom/your-program-of-study/program-options/finance">Finance</a></li>
# <li><a href="https://telfer.uottawa.ca/en/bcom/your-program-of-study/program-options/human-resource-management">Human Resource Management</a></li>
# <li><a href="https://telfer.uottawa.ca/en/bcom/your-program-of-study/program-options/international-management">International Management</a></li>
# <li><a href="https://telfer.uottawa.ca/en/bcom/your-program-of-study/program-options/management">Management</a></li>
# <li><a href="https://telfer.uottawa.ca/en/bcom/your-program-of-study/program-options/marketing">Marketing</a></li>
# <li><a href="https://telfer.uottawa.ca/en/bcom/your-program-of-study/program-options/misa">Management Information Systems (MIS)</a></li>
# <li><a href="https://telfer.uottawa.ca/en/mba">Master of Business Administration</a></li>
# <li><a href="https://telfer.uottawa.ca/en/mha">Master of Health Administration</a></li>
# </ul> </div>
# </div>
# </div>
# </div>
# </details>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="uos--full-width">
# <div class="uottawa-B">
# <div class="uottawa-B-1">
# <div class="uottawa-B-1-1o1 uol--region">
# <div class="panel-pane pane-snippet cd-survey">
# <div class="uos--standard-width">
# <div class="uoe--view-mode uoe--view-mode--content-body content-snippet uoe--content">
# <style>
# /* Button used to open the survey form - fixed at the bottom of the page */
# .cd-survey{
# 	margin-top: 30px!important;
# }
#
# .smcx-embed{
# 	border:2px solid #2d2d2c!important;
# 	border-bottom:none!important;
# 	border-radius:0!important;
# }
#
# .open-button {
# 	background-color: #2d2d2c;
# 	color: white;
# 	border: none;
# 	cursor: pointer;
# 	opacity: 0.85;
# 	width: 400px;
# 	height: 50px;
# 	font-weight: bold;
# 	background-image: url("https://www.uottawa.ca/sites/www.uottawa.ca/files/back-to-top.png");
# 	background-repeat: no-repeat;
# 	background-position: center right;
# }
#
# #f {
#     width: 980px;
#     position: fixed;
#     bottom: 0px;
# 	left: 50%;
# 	-webkit-transform: translateX(-50%);
#     -ms-transform: translateX(-50%);
#     transform: translateX(-50%);
# 	z-index: 1;
# 	display:none;
# }
#
# /* The popup survey - hidden by default */
# @supports (-webkit-overflow-scrolling: touch) {
#   .smcx-iframe-container {
#     -webkit-overflow-scrolling:touch !important;
#     overflow:auto !important;
#   }
# }
#
# .survey-popup {
# 	display: none;
# 	position: absolute;
# 	bottom: 0;
# 	border-bottom:none;
# 	background-color: white;
# 	width: 400px;
# 	border-bottom: none;
# }
#
# /* Set a style for the submit/send button */
# .survey-popup .btn {
# 	background-color: #2d2d2c;
# 	color: white;
# 	border: none;
# 	cursor: pointer;
# 	width: 100%;
# 	opacity: 0.85;
# 	height: 50px;
# 	font-weight: bold;
# 	background-image: url("https://www.uottawa.ca/sites/www.uottawa.ca/files/down-to-bottom.png");
# 	background-repeat: no-repeat;
# 	background-position: center right;
# }
#
# /* Add some hover effects to buttons */
# .survey-popup .btn:hover, .open-button:hover {
# 	opacity: 1;
# }
#
# @media only screen and (min-width: 1367px){
# 	#f {
# 		width: 1185px;
# 	}
# }
#
# @media only screen and (min-width: 736px) and (max-width: 995px) {
# 	#f {
# 		width: 720px;
# 	}
# }
#
# @media (max-width: 735px) and (min-width: 0px){
# 	#f {
# 		width: auto;
# 		left: 10px;
# 		-webkit-transform: none;
# 		-ms-transform: none;
# 		transform: none;
# 	}
# 	.survey-popup, .open-button {
# 		width: 340px;
# 	}
# }
#
# </style>
# <div id="f">
# <button class="open-button" onclick="openForm()">Help us improve this page</button>
# <div class="survey-popup" id="myForm">
# <script>(function(t,e,s,n){var o,a,c;t.SMCX=t.SMCX||[],e.getElementById(n)||(o=e.getElementsByTagName(s),a=o[o.length-1],c=e.createElement(s),c.type="text/javascript",c.async=!0,c.id=n,c.src=["https:"===location.protocol?"https://":"http://","widget.surveymonkey.com/collect/website/js/tRaiETqnLgj758hTBazgd5IivfPEhj_2FUp_2BRFniVOKyomQtA4haTrXSGM_2FH1nbbLD.js"].join(""),a.parentNode.insertBefore(c,a))})(window,document,"script","smcx-sdk");</script>
# <button class="btn" onclick="closeForm()" type="button">Help us improve this page</button>
# </div>
# </div>
# <!--
# //line moved in Blocks -> Global Header -> CD-Hacks
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js"></script>
# -->
# <script>
# function openForm() {
#   $("#myForm").css({display: 'block'});
# }
#
# function closeForm() {
#   $("#myForm").css({display: 'none'});
# }
#
# 	var windw = $(window);
#
# 	$.fn.followTo = function (pos) {
# 		var $this = this,
# 			$window = $(windw);
#
# 			if ($window.scrollTop() + $window.height()  > $('#page-wrapper').height() - pos + 30) {
# 				$this.css({
# 					position: 'absolute',
# 					bottom: pos
# 				});
# 			} else {
# 				$this.css({
# 					position: 'fixed',
# 					bottom: 0
# 				});
# 			}
#
# 		$window.scroll(function(e){
# 			if ($window.scrollTop() + $window.height()  > $('#page-wrapper').height() - pos + 30) {
# 				$this.css({
# 					position: 'absolute',
# 					bottom: pos
# 				});
# 			} else {
# 				$this.css({
# 					position: 'fixed',
# 					bottom: 0
# 				});
# 			}
# 		});
# 	};
#
# 	$(window).resize(function() {
# 		if ( $('#contact-footer-wrapper').length ) {
# 			$surveyPaddingBottom = $('#global-footer-wrapper').outerHeight() + $('#contact-footer-wrapper').outerHeight();
# 		} else {
# 			$surveyPaddingBottom = $('#global-footer-wrapper').outerHeight();
# 		}
# 		$('#main-content-wrapper').css('padding-bottom', $surveyPaddingBottom);
# 		$('#contact-footer-wrapper').css('bottom', $('#global-footer-wrapper').outerHeight());
# 		$('#f').followTo($surveyPaddingBottom);
# 	  });
#
# $(window).load(function(){
# 	if ( $('#contact-footer-wrapper').length ) {
# 		$surveyPaddingBottom = $('#global-footer-wrapper').outerHeight() + $('#contact-footer-wrapper').outerHeight();
# 	} else {
# 		$surveyPaddingBottom = $('#global-footer-wrapper').outerHeight();
# 	}
# 	$('#f').followTo($surveyPaddingBottom);
# 	$('#f').css({display: 'block'});
# });
# </script> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </main>
# <a class="uoe--back-top" href="#main-content">Back to top</a>
# </div>
# <div class="uol--clearfix" id="contact-footer-wrapper">
# <div class="uol--page-container" id="contact-footer">
# <div class="contact-footer-item-wrapper uol--width--1000"><div class="uos--full-width">
# <div class="uottawa-B">
# <div class="uottawa-B-1">
# <div class="uottawa-B-1-1o1 uol--region">
# <div class="uos--standard-width--always uos--standard-width cs-widget" id="--28"><div class="uos--view-mode-block--clearfix cs-content-wrapper"><div class="uos--standard-width--always uos--standard-width cs-widget" id="--27"><div class="uos--view-mode-block--clearfix cs-content-wrapper">
# <div class="uos--standard-width">
# <div class="uoe--view-mode uoe--view-mode--content-body content-snippet uoe--content">
# <div class="cd-local-footer-container">
# <div class="cd-local-footer-left"><p>Updated by <a href="mailto:commweb@uOttawa.ca">Communications Directorate</a></p></div>
# <div class="cd-local-footer-right"><a class="uoe--back-top" href="#main-content">Back to top</a></div>
# </div> </div>
# </div></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="uol--clearfix" id="global-footer-wrapper">
# <div id="global-footer">
# <div class="uos--full-width">
# <div class="uottawa-B">
# <div class="uottawa-B-1">
# <div class="uottawa-B-1-1o1 uol--region">
# <div class="panel-pane pane-snippet">
# <div class="uos--standard-width">
# <div class="uoe--view-mode uoe--view-mode--content-body content-snippet uoe--content">
# <script type="text/javascript">
# /*<![CDATA[*/
# (function() {
# var sz = document.createElement('script'); sz.type = 'text/javascript'; sz.async = true;
# sz.src = '//siteimproveanalytics.com/js/siteanalyze_3553.js';
# var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(sz, s);
# })();
# /*]]>*/
# </script> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="uol--page-container" id="uottawa-global-footer">
# <div id="uottawa-global-contact-footer">
# <div id="uottawa-footer-logo">
# <a href="https://www.uottawa.ca/en" hreflang="" lang="" rel="home" title="Home"><img alt="University of Ottawa Logo" src="https://www.uottawa.ca/sites/all/themes/custom/uottawa_zen_assets/images/uOttawaLogo.svg"/></a> </div>
# <p><a href="https://www.uottawa.ca/en/contact" hreflang="" lang=""><span class="uos--social--contact"></span>Contact the University</a> </p>
# <p><a href="https://www.uottawa.ca/en/contact" hreflang="" lang=""><span class="uos--social--map"></span><span class="uos--address">75 Laurier Ave. East, Ottawa ON<br/>K1N 6N5 Canada</span></a> </p>
# </div>
# <div class="uottawa-div-only-desktop">
# <div class="uottawa-global-footer-links">
# <ul class="uottawa-global-footer-links-common">
# <li class="first collapsed"><a href="https://www.uottawa.ca/about" hreflang="" lang="">About uOttawa</a></li>
# <li class="leaf"><a href="https://media.uottawa.ca/" hreflang="" lang="">Media</a></li>
# <li class="last leaf"><a href="https://www.uottawa.ca/aipo/privacy" hreflang="" lang="">Privacy</a></li>
# </ul>
# <ul class="uottawa-global-footer-links-common">
# <li class="first collapsed"><a href="https://uozone2.uottawa.ca/?language=en" hreflang="" lang="">uoZone</a></li>
# <li><a class="siteinfonav-library" href="https://biblio.uottawa.ca/en" hreflang="" lang="">Library</a></li>
# <li><a href="https://www.uottawa.ca/en/a-z" hreflang="" lang="">A-Z Index</a></li>
# </ul>
# <ul class="uottawa-global-footer-links-common">
# <li><a class="siteinfonav-accessibility" href="https://www.uottawa.ca/respect/accessibility-hub/" hreflang="" lang="">Accessibility</a></li>
# <li class="collapsed"><a href="https://www.uottawa.ca/en/employees" hreflang="" lang="">Employees</a></li>
# <li class="leaf"><a href="https://www.uottawa.ca/human-resources/jobs" hreflang="" lang="">Jobs</a></li>
# </ul>
# <ul class="uottawa-global-footer-links-common">
# <li><a class="siteinfonav-policies" href="https://www.uottawa.ca/about/policies-and-regulations" hreflang="" lang="">Policies</a></li>
# <li><a class="siteinfonav-copyright" href="https://copyright.uottawa.ca" hreflang="" lang="">Copyright</a></li>
# <li><a class="siteinfonav-governance" href="https://www.uottawa.ca/administration-and-governance" hreflang="" lang="">Governance</a></li>
# </ul>
# </div>
# </div>
# <div class="uottawa-div-only-mobile">
# <div class="uottawa-global-footer-links">
# <ul class="uottawa-global-footer-links-common">
# <li class="last leaf"><a href="https://www.uottawa.ca/about" hreflang="" lang="">About uOttawa</a></li>
# <li><a class="siteinfonav-accessibility" href="https://www.uottawa.ca/respect/accessibility-hub/" hreflang="" lang="">Accessibility</a></li>
# <li class="leaf"><a href="https://media.uottawa.ca/" hreflang="" lang="">Media</a></li>
# <li class="collapsed"><a href="https://www.uottawa.ca/en/employees" hreflang="" lang="">Employees</a></li>
# <li class="last leaf"><a href="https://www.uottawa.ca/aipo/privacy" hreflang="" lang="">Privacy</a></li>
# <li class="leaf"><a href="https://www.uottawa.ca/human-resources/jobs" hreflang="" lang="">Jobs</a></li>
# </ul>
# <ul class="uottawa-global-footer-links-common">
# <li class="first collapsed"><a href="https://uozone2.uottawa.ca/?language=en" hreflang="" lang="">uoZone</a></li>
# <li><a class="siteinfonav-policies" href="https://www.uottawa.ca/about/policies-and-regulations" hreflang="" lang="">Policies</a></li>
# <li><a class="siteinfonav-library" href="https://biblio.uottawa.ca/en" hreflang="" lang="">Library</a></li>
# <li><a class="siteinfonav-copyright" href="https://copyright.uottawa.ca" hreflang="" lang="">Copyright</a></li>
# <li><a href="https://www.uottawa.ca/en/a-z" hreflang="" lang="">A-Z Index</a></li>
# <li><a class="siteinfonav-governance" href="https://www.uottawa.ca/administration-and-governance" hreflang="" lang="">Governance</a></li>
# </ul>
# </div>
# </div>
# <div class="clearfix"></div>
# </div>
# <div id="uottawa-global-footer-social">
# <div class="uol--page-container">
# <div>
# <div id="uottawa-last-emergency">
# <a href="https://www.uottawa.ca/en/emergency" hreflang="" lang=""><span class="uos--invisible">On-Campus</span> Emergency</a> </div>
# <ul class="uos--social" id="uottawa-global-footer-links-social">
# <li class="first leaf"><a class="uos--social--youtube" href="https://www.youtube.com/uottawa" hreflang="" lang="" target="_blank"><span class="uos--invisible">Visit the University of Ottawa's Youtube profile</span></a></li>
# <li class="leaf"><a class="uos--social--linkedin" href="https://www.linkedin.com/school/uottawa/" hreflang="" lang="" target="_blank"><span class="uos--invisible">Visit the University of Ottawa's LinkedIn profile</span></a></li>
# <li class="leaf"><a class="uos--social--instagram" href="https://www.instagram.com/uottawa/?hl=en" hreflang="" lang="" target="_blank"><span class="uos--invisible">Visit the University of Ottawa's Instagram profile</span></a></li>
# <li class="leaf"><a class="uos--social--twitter" href="https://twitter.com/uottawa" hreflang="" lang="" target="_blank"><span class="uos--invisible">Visit the University of Ottawa's Twitter profile</span></a></li>
# <li class="leaf"><a class="uos--social--facebook" href="https://www.facebook.com/uottawa" hreflang="" lang="" target="_blank"><span class="uos--invisible">Visit the University of Ottawa's Facebook profile</span></a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script>
#     /*<![CDATA[*/
#     (function() {
#     var sz = document.createElement('script'); sz.type = 'text/javascript'; sz.async = true;
#     sz.src = '//siteimproveanalytics.com/js/siteanalyze_3553.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(sz, s);
#     })();
#     /*]]>*/</script>
# </body>
# </html>

# %% [markdown]
# Fourth, find an element with its attribute name.
#
# ###Syntax: find_all(name, attrs)
# Find all elements following the same syntax rules.
#
# ## 4. Extract faculty.

# %%
# Find faculty: save as list

faculty = [faculty.text for faculty in soup.find_all('h2')]
faculty
# Out:
# ['Faculty of Arts',
#  'Faculty of Education',
#  'Faculty of Engineering',
#  'Faculty of Health Sciences',
#  'Faculty of Law - Civil Law Section',
#  'Faculty of Law - Common Law Section',
#  'Faculty of Medicine',
#  'Faculty of Science',
#  'Faculty of Social Sciences',
#  'Telfer School of Management']

# %% [markdown]
# # Export to CSV
# Import neccesary packages. The file will be saved in the virtual machine, so in order to download a csv file to your local computer, you need to import *files* from google.colab.
#
# ## 1. Packages
#
# *   [pandas](https://pandas.pydata.org/): open source, BSD-licensed library providing high-performance, easy-to-use data structures and data analysis tools.

# %%
# import
import pandas as pd
from google.colab import files

# %% [markdown]
# ## 2. DataFrame

# %%
# Create an empty data frame
df = pd.DataFrame(faculty)
df
# Out:
#                                      0
# 0                      Faculty of Arts
# 1                 Faculty of Education
# 2               Faculty of Engineering
# 3           Faculty of Health Sciences
# 4   Faculty of Law - Civil Law Section
# 5  Faculty of Law - Common Law Section
# 6                  Faculty of Medicine
# 7                   Faculty of Science
# 8           Faculty of Social Sciences
# 9          Telfer School of Management

# %% [markdown]
# You can save df (Data frame) to csv format using df.to_csv().
#
# ## 3. Save as CSV

# %%
# Save df as csv in the virtual machine provided by Google
df.to_csv('uOttawa_faculty.csv', sep='\t', encoding='utf-8')

# Download the file to your computer
files.download("uOttawa_faculty.csv")
